# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt

files = glob.glob('../datasets/images/*.JPG')

img_path = files[1]
img = cv2.imread(img_path)

hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

mask0 = cv2.inRange(hsv, (0, 0, 0), (255, 120, 255))

new_img = img.copy()
new_img[np.where(mask0)] = 255

plt.imshow(mask)
plt.title('mask')
plt.show()

plt.imshow(new_img)
plt.title('new_img')
plt.show()
